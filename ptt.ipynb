# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
r = Request("https://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html")
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
# html

# %%
import requests
response = requests.get("https://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html")
html = BeautifulSoup(response.text)
html
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>[負雷]一屍到底  - 看板 movie - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="雷文防雷資訊頁
# ~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~
# 1.影片名稱 :一屍到底
# 2.觀影時間 : / 拒答
# 3.觀影地點 : 戲院名稱 / 住家網路 / 其他等地點 (單選:自行刪除選項) / 拒答
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[負雷]一屍到底 " property="og:title"/>
# <meta content="雷文防雷資訊頁
# ~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~
# 1.影片名稱 :一屍到底
# 2.觀影時間 : / 拒答
# 3.觀影地點 : 戲院名稱 / 住家網路 / 其他等地點 (單選:自行刪除選項) / 拒答
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html" rel="canonical"/>
#
# <link href="//images.ptt.cc/bbs/v2.25/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
#
#
# 	</head>
#     <body>
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <div id="topbar-container">
# 	<div class="bbs-content" id="topbar">
# 		<a href="/bbs/" id="logo">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/movie/index.html"><span class="board-label">看板 </span>movie</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div class="bbs-content" id="navigation">
# 		<a class="board" href="/bbs/movie/index.html">返回看板</a>
# 		<div class="bar"></div>
# 		<div class="share">
# 			<span>分享</span>
# 			<div class="fb-like" data-href="http://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html" data-layout="button_count" data-send="false" data-show-faces="false" data-width="90"></div>
#
# 			<div class="g-plusone" data-size="medium"></div>
# <script type="text/javascript">
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
# </script>
#
# 		</div>
# 	</div>
# </div>
# <div id="main-container">
#     <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">ea9715234 (雞蓉玉米湯)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">movie</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[負雷]一屍到底 </span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Wed Oct 10 23:02:24 2018</span></div>
# 雷文防雷資訊頁
#
# ~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~
#
#
# 1.影片名稱 :一屍到底
#
# 2.觀影時間 : / 拒答
#
# 3.觀影地點 : 戲院名稱 / 住家網路 / 其他等地點 (單選:自行刪除選項) / 拒答
#
# 4.觀影方式 : 自行購票 / 片商(商家)邀約 / 電視 / 網路 (單選:自行刪除選項) /拒答
#
# §其他防雷說明(非必要) : n刷等其他說明請於此區說明....可留空
#
#
#
# ~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~
# 此區為發文防雷頁
# 可選擇性提供上列 1~4 資訊  或不提供亦可
# 觀影心得於分隔線下方發布即可
#
# ~~~~~~~~~~~~~~~~~~~ 雷文 主文分隔線 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# 實在不懂這種糞片為什麼負雷文的比例之低，這其實很不尋常
#
# 不管什麼片，只要有點人氣，多少都會有一點負雷文
#
# 但一屍到底的負雷文篇數非常少，難道真的有這麼神?
#
# 其實從來沒有寫負雷文的經驗，為了平衡一下，特地撰寫此負雷文，文筆不好請見諒
#
# 1.前37分鐘，鏡頭搖晃、演技僵硬、劇情連結不流暢，我想這應該大家都很有共識，
#
# 連片商都說要忍耐前37分鐘，所以這段就是糞應該沒有爭議吧。
#
# 2.電影中段的拍片起源及角色背景，這段就很平庸，只是想凸顯這些演員就是臨時
#
# 湊起的，而且幾乎每個都是怪咖，所以拍片的過程很艱辛，板上所推的笑點及精華應該也
#
# 不是在這段，而且關於演技的部分導演的堅持有其必要嗎?這部份下段再詳述。
#
# 3.大嬸加入演出，拜託要演就照稿演出好不，什麼叫做演戲就會失控阿，我知道是劇情設
#
# 定，但是這樣的人你也敢用?那導演你對這部影片我看也不是很負責任嘛，對應你原本得
#
# 過且過的態度也是滿符合的，而且那個"碰"是哪裡好笑?難笑得要死，根本就是對於防身
#
# 術的輕蔑，才會有這樣的表演，在我看來非常地不尊重專業，而沒人可用就跟觀眾道歉改
#
# 天再直播就好，觀眾要看得是好的作品!!誰管你幾鏡阿，你拍了一萬次也不甘我的事，
#
# 就算是節目製作單位要求的，當天人家就說要卡了，充其量不過是想滿足自己的虛榮心。
#
# 當其他電視公司都王八蛋?別人這麼用心，結果你這樣隨便拍就想拿來當節目?我還
#
# 不如去看正妹吃東西聊天直播。
#
# 4.第三人稱視角的一屍到底拍片精華，這段應該就是所謂讓人笑翻天及好看的段落?在我看
#
# 來看第一次的糞片已經夠辛苦了，還要看糞片是怎麼拍成的，根本是折磨第二次阿，
#
# 而導演對於眼淚及驚恐的演技為什麼這麼堅持?不覺得很諷刺嗎?當初節目製作人就說要卡，
#
# 結果硬要繼續拍，請問一下，你到底是想要完成拍一鏡到底還是要拍出好的東西給觀眾?
#
# 拍成功了一鏡到底結果作品根本就是垃圾，以你導演這高水準，你認為這樣可以嗎?你可以
#
# 接受這樣的作品嗎?如果可以的話為什麼還要這樣要求別人的演技，反正得過且過就好，
#
# 就像你之前的人生一樣。要嘛就演練到真的能一鏡到底再開機拍攝，連演員都沒搞定就想
#
# 拍，那人家為什麼不能點眼藥水?真的是笑死人的雙重標準。
#
# 5.其他負雷點:角色顏值都很低，大概只有年輕男主角比較帥。演技浮誇，這也算讓人笑
#
# 翻的點之一嗎?尖叫聲太久很吵等等
#
# 6.1負雷文易噓點，負雷文很容易被噓，其中有兩點是覺得很荒謬，當別人說出不好笑的時
#
# 候，說本片不是搞笑/喜劇片，我是不知道這種分類有啥意義啦，劇情、驚悚、喜劇、恐怖
#
# 應該都有沾到一點吧?所以如果有分類到驚悚的部分我一樣可以批評不驚悚吧，還要被說日
#
# 子是不是很難過，我才覺得會笑出來的人是腦袋有問題好嗎
#
# 6.2 說電影喜不喜歡是個人主觀感受，那你幹嘛又要來噓負雷文?或者你們應該去跟那些噓
#
# 負雷文的人講這句話吧，這是我負雷的主觀感受，你不認同硬要在下面護航是要幹嘛?就
#
# 算真的沒有工讀生人家也覺得你是工讀生啦，我看不過就是盲目崇拜跟風的假文青吧，沒
#
# 辦法接受自己的信仰被挑戰，或者是一種從眾效應。希望看到此篇負雷文有共鳴的人，能
#
# 夠撰文平衡，無論言之有物或無物。
#
#
#
#
#
#
#
#
#
#
#
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 101.15.153.236
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html" rel="nofollow" target="_blank">https://www.ptt.cc/bbs/movie/M.1539183746.A.DF0.html</a>
# </span><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">a4040856    </span><span class="f3 push-content">: 如果你有跟一些奇葩或是雷包組隊一起做事情你就會</span><span class="push-ipdatetime"> 10/10 23:05
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">a4040856    </span><span class="f3 push-content">: 了解了</span><span class="push-ipdatetime"> 10/10 23:05
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">monguly00   </span><span class="f3 push-content">: 負雷+1</span><span class="push-ipdatetime"> 10/10 23:07
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">vKHip       </span><span class="f3 push-content">: 這部當初那麼多好評就覺得很怪了</span><span class="push-ipdatetime"> 10/10 23:09
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">XZXie       </span><span class="f3 push-content">: 看在打那麼多字  給你一點墨水分數吧</span><span class="push-ipdatetime"> 10/10 23:09
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">vKHip       </span><span class="f3 push-content">: 懷疑有些根本是反串 看到爛片不甘心也來打一篇好雷</span><span class="push-ipdatetime"> 10/10 23:10
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 結尾說的中肯，只要些許懷疑(也是在負雷文那質疑)就</span><span class="push-ipdatetime"> 10/10 23:10
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 馬上過來砲你或是積極解釋不是工讀生，真的覺得很好</span><span class="push-ipdatetime"> 10/10 23:10
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 笑XD</span><span class="push-ipdatetime"> 10/10 23:10
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jcyoaa      </span><span class="f3 push-content">: 這片讓我對ptt電影版完全放棄。完全業配霸佔</span><span class="push-ipdatetime"> 10/10 23:11
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 你覺得是負雷，喜歡的人不能反駁？反駁就變工讀生</span><span class="push-ipdatetime"> 10/10 23:12
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: ？更何況像我也都一直強調不喜歡又沒關係，是每個</span><span class="push-ipdatetime"> 10/10 23:12
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 人的自由啊，只是厭惡把喜歡的人說成是工讀生的那</span><span class="push-ipdatetime"> 10/10 23:12
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 種人而已(又要新開戰場了嗎？XD)</span><span class="push-ipdatetime"> 10/10 23:12
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 有興趣可以查詢我id在本版的文章, 或者搜尋一屍</span><span class="push-ipdatetime"> 10/10 23:13
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 就說指控有工讀生的人，直接指名是哪個id ，並提出</span><span class="push-ipdatetime"> 10/10 23:15
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 證據，我們交給板主來處理嘛！這麼簡單的事都做不</span><span class="push-ipdatetime"> 10/10 23:15
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 到</span><span class="push-ipdatetime"> 10/10 23:15
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 要反駁、要推廣自己去寫文章，不用來別人文章下說明</span><span class="push-ipdatetime"> 10/10 23:17
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">aul4xu44    </span><span class="f3 push-content">: 同意，超爛的片，浪費時間的片....</span><span class="push-ipdatetime"> 10/10 23:17
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 標題就是負雷文 你跟我解釋好雷要幹嘛?其心可議嘛</span><span class="push-ipdatetime"> 10/10 23:17
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 沒人說誰是工讀生 是這樣的行為很像 中文再去練練吧</span><span class="push-ipdatetime"> 10/10 23:18
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">egain       </span><span class="f3 push-content">: 放棄電影版 那你可以去yahoo電影討論區  那邊給這片</span><span class="push-ipdatetime"> 10/10 23:18
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">egain       </span><span class="f3 push-content">: 超低分  然後給歐洲攻略超高分  推薦去看歐洲攻略^^</span><span class="push-ipdatetime"> 10/10 23:18
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 寫文章又不准別人在底下留言@@</span><span class="push-ipdatetime"> 10/10 23:18
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 原po抱歉, 借我推廣一下, 因為Za常常找負評的麻煩</span><span class="push-ipdatetime"> 10/10 23:19
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 我又不是跟原po 說話，你想太多了</span><span class="push-ipdatetime"> 10/10 23:19
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: Za認為有問題的點我都在那幾篇解釋過了, 但他還是</span><span class="push-ipdatetime"> 10/10 23:20
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: free 你就針對我上面的要求回應就好啊，很困難？</span><span class="push-ipdatetime"> 10/10 23:20
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 現在又延伸到不准留言 也是神邏輯</span><span class="push-ipdatetime"> 10/10 23:20
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">medlife0830 </span><span class="f3 push-content">: 就爛片 也被吹成神作 ..</span><span class="push-ipdatetime"> 10/10 23:21
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 但他還是在別人文章下說三道四, 搬弄是非.</span><span class="push-ipdatetime"> 10/10 23:21
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">nanio       </span><span class="f3 push-content">: 推 真的蠻普通的片 不知道紅什麼...</span><span class="push-ipdatetime"> 10/10 23:21
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 某z又來了～</span><span class="push-ipdatetime"> 10/10 23:21
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 你的問題是什麼請直說, 我人就在這裡. 或者PO一篇文</span><span class="push-ipdatetime"> 10/10 23:22
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 只要有負雷文一定有他 真的很愛爛片呢</span><span class="push-ipdatetime"> 10/10 23:22
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 別人在家討論串下面講這些有的沒的</span><span class="push-ipdatetime"> 10/10 23:22
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 就說指控有工讀生的人……那句啊</span><span class="push-ipdatetime"> 10/10 23:22
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jamwu       </span><span class="f3 push-content">: 希望能像原po文筆 發負雷文 但我怕怕...</span><span class="push-ipdatetime"> 10/10 23:24
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 那篇文章是143499那篇文章, 我再這裡再跟你講一遍</span><span class="push-ipdatetime"> 10/10 23:24
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我原文的意旨是好雷容易被操作, 要大家謹慎篩選</span><span class="push-ipdatetime"> 10/10 23:25
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我有說好雷都是工讀生這種話嗎? 那篇文都沒刪</span><span class="push-ipdatetime"> 10/10 23:26
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 你可以從頭到尾檢視過一次, 而我的立場也很簡單</span><span class="push-ipdatetime"> 10/10 23:27
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 因為板規問題, 導致認真寫文章的人被迫要和行銷文</span><span class="push-ipdatetime"> 10/10 23:27
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 就把每篇負雷文都扯工讀生進來阿 混淆負雷主旨也不</span><span class="push-ipdatetime"> 10/10 23:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 會把這部變神啦 爛片就是爛片</span><span class="push-ipdatetime"> 10/10 23:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 混在一起, 我厭惡的不是好雷, 而是躲在好雷背後的</span><span class="push-ipdatetime"> 10/10 23:28
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">a5178934    </span><span class="f3 push-content">: PTT少數人發篇負雷還要說好雷的都是工讀生 真是夠了</span><span class="push-ipdatetime"> 10/10 23:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 那些行銷文, 汙染了整個好雷, 如果你也是個認真寫文</span><span class="push-ipdatetime"> 10/10 23:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 的人, 立場不也要和我一致才對?</span><span class="push-ipdatetime"> 10/10 23:29
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 護航方式剩下po負雷文的都說po好雷的是工讀生了嗎？</span><span class="push-ipdatetime"> 10/10 23:30
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">:  爛片講不出所以然所以只能這樣護航喔</span><span class="push-ipdatetime"> 10/10 23:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jen10969    </span><span class="f3 push-content">: 負雷的原因都是劇情設定欸XD</span><span class="push-ipdatetime"> 10/10 23:30
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 不去針對問題的來源, 反而是反咬我一口, 我就不明白</span><span class="push-ipdatetime"> 10/10 23:30
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: Za你再去看看我那篇文章, 有什麼問題再問我</span><span class="push-ipdatetime"> 10/10 23:30
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 別在這裡亂咬人, 不然我看一次就宣導一次, 反正</span><span class="push-ipdatetime"> 10/10 23:31
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我文章都不刪, 就留給網友來評價.</span><span class="push-ipdatetime"> 10/10 23:31
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 我不是電影人當然只能針對劇情寫負雷阿 其他我不懂</span><span class="push-ipdatetime"> 10/10 23:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 原PO不好意思, 不得已才在你文章串下宣傳.</span><span class="push-ipdatetime"> 10/10 23:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 一直戰這點的那幾個id ，意思是說被很多好雷騙進來</span><span class="push-ipdatetime"> 10/10 23:34
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: ，這不就代表在騙的是多數？(如果沒那麼多，他們也</span><span class="push-ipdatetime"> 10/10 23:34
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 不會想看，這不就是地圖砲？)</span><span class="push-ipdatetime"> 10/10 23:34
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 不過這也是避免, 某些點被拿去扭曲來攻擊你們.</span><span class="push-ipdatetime"> 10/10 23:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Guoplus     </span><span class="f3 push-content">: 看到沒有負雷特地來負也是蠻可愛的</span><span class="push-ipdatetime"> 10/10 23:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 別傻了啦1986 你發負雷他認為就是不同立場了啦</span><span class="push-ipdatetime"> 10/10 23:35
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 所以free 是認為有工讀生，但只是少數囉</span><span class="push-ipdatetime"> 10/10 23:36
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 別在那邊跟我東扯西扯, 什麼少數多數又有什麼問題了</span><span class="push-ipdatetime"> 10/10 23:37
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 我不就說尊重原po 不喜歡的權利了嗎</span><span class="push-ipdatetime"> 10/10 23:37
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我跟你說啦, 板規4就說明了, 容許部分行銷行為了</span><span class="push-ipdatetime"> 10/10 23:38
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">gtcb        </span><span class="f3 push-content">: 雖然你寫得還不錯，但是我還是很愛這部。</span><span class="push-ipdatetime"> 10/10 23:38
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 已經容許了還怕人家質疑有沒有阿?</span><span class="push-ipdatetime"> 10/10 23:38
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 一邊說尊重 一邊說別人說好雷的都是工讀生 真尊重耶</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 板規4 a、口碑行銷活動產生的正常心得文不視為違規</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我沒說好雷都是工讀生阿, 我哪時候說的? 你po給我看</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我原文不是夠清楚了, 好雷容易被操作</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 多數少數怎麼不是問題，你看其他說有工讀生的人ex</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: lamigirl 那篇說什麼:業配文實在太多了，這明顯就</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 跟free 說只有少數是業配的說法不一樣啊</span><span class="push-ipdatetime"> 10/10 23:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 容易被操作=好雷都是工讀生喔, 神邏輯</span><span class="push-ipdatetime"> 10/10 23:40
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 少數多數跟我的立場又有什麼關聯?</span><span class="push-ipdatetime"> 10/10 23:41
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 這問題的根本就是板規4給人瓜田李下的機會</span><span class="push-ipdatetime"> 10/10 23:41
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 而不是什麼少數多數的, 你理解了沒?</span><span class="push-ipdatetime"> 10/10 23:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">CalvinS     </span><span class="f3 push-content">: 幫推</span><span class="push-ipdatetime"> 10/10 23:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 所以你確定是有工讀生？</span><span class="push-ipdatetime"> 10/10 23:42
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">xxx22088    </span><span class="f3 push-content">: 一鏡到底是長官/老闆丟下來的蠢主意</span><span class="push-ipdatetime"> 10/10 23:43
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 有沒有工讀生我不知道, 但我知道好雷容易被操作</span><span class="push-ipdatetime"> 10/10 23:43
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: 樓上有看電影嗎?中間有要卡喔</span><span class="push-ipdatetime"> 10/10 23:43
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 要大家選片的時候閃好雷遠一點</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jamwu       </span><span class="f3 push-content">: 我唸書時有在圖書館當過工讀生 算嗎？</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">zss40401    </span><span class="f3 push-content">: 唉那我也不跟你們解釋</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zss40401    </span><span class="f3 push-content">: 一句話</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zss40401    </span><span class="f3 push-content">: 可悲取暖集散地</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 你不知道，那其他說有工讀生的id 知道確實有工讀生</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 嗎？</span><span class="push-ipdatetime"> 10/10 23:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 這爛片也很夠了啦 造成大討論</span><span class="push-ipdatetime"> 10/10 23:45
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 他們說了又怎樣? 板規4放任行銷文, 還怕被講喔</span><span class="push-ipdatetime"> 10/10 23:45
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: kb 說啊，你敢肯定有工讀生？</span><span class="push-ipdatetime"> 10/10 23:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 人家充其量也是說部分, 疑似之類的, 你就每次要解讀</span><span class="push-ipdatetime"> 10/10 23:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 成, 好雷=工讀生 , 我就是不懂你的邏輯啦</span><span class="push-ipdatetime"> 10/10 23:47
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: z真是令人作嘔 每篇負雷文都看到你來亂</span><span class="push-ipdatetime"> 10/10 23:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">luj2        </span><span class="f3 push-content">: 這部片真的很難看，我推原po</span><span class="push-ipdatetime"> 10/10 23:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 有那規定就一定有人這麼做？</span><span class="push-ipdatetime"> 10/10 23:47
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 還是你邏輯上就是連人家懷疑的權利都要剝奪?</span><span class="push-ipdatetime"> 10/10 23:47
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我不知道你在公三小啦 講清楚點</span><span class="push-ipdatetime"> 10/10 23:48
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 懷疑？那疑點在哪？</span><span class="push-ipdatetime"> 10/10 23:48
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Ryspon      </span><span class="f3 push-content">: 大負雷+1</span><span class="push-ipdatetime"> 10/10 23:48
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 你問我那麼多次, 要不要讓我問你一下?</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">waynehow    </span><span class="f3 push-content">: 只認同第6點</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 你問啊</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我回答你最後一個問題, 疑點就是板規4</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jessica87270</span><span class="f3 push-content">: 覺得浪費時間浪費錢+1</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我問你, 你的立場是替好雷抱不平的嗎?</span><span class="push-ipdatetime"> 10/10 23:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ptrpan      </span><span class="f3 push-content">: 給箭頭，我是沒要噓評論的部分，那是你的自由，但是</span><span class="push-ipdatetime"> 10/10 23:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kindochan   </span><span class="f3 push-content">: 大負雷+2，第一次沒看完電影就離場，不知所云！</span><span class="push-ipdatetime"> 10/10 23:51
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ptrpan      </span><span class="f3 push-content">: 有些言語上接近人身攻擊的語法，不太洽當</span><span class="push-ipdatetime"> 10/10 23:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">idlebeast   </span><span class="f3 push-content">: 負雷+1</span><span class="push-ipdatetime"> 10/10 23:51
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">qoo4628802  </span><span class="f3 push-content">: ㄏ</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: zakijudelo?? 我還在等你回答我的問題</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 這什麼爛疑點XD，要說疑點是要針對個別的好雷文中</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 有什麼顯可疑在行銷這種才叫疑點吧，如果只是板規</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 定說可以行銷，那你是不是要質疑所有電影的好雷文</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 都可能是業配了？</span><span class="push-ipdatetime"> 10/10 23:53
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 我打比較慢啦XD</span><span class="push-ipdatetime"> 10/10 23:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: z你完全沒回答到free的問題啊@@</span><span class="push-ipdatetime"> 10/10 23:54
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 又再繞迴圈了, 你回答我的問題吧</span><span class="push-ipdatetime"> 10/10 23:54
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 是看不懂中文 還是避重就輕想模糊焦點 我看兩者都是</span><span class="push-ipdatetime"> 10/10 23:55
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 吧呵呵</span><span class="push-ipdatetime"> 10/10 23:55
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 好雷容易被操做 真好操作阿XD 操作到日本大咖一堆人</span><span class="push-ipdatetime"> 10/10 23:55
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 他就是每篇都這樣打爛仗阿, 整天追殺</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 現在跑到哪個問題了？我剛剛那個沒回答到？</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 一直跳針攻訐懷疑有工讀帶風向情勢的版友 要你解釋</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 自己護航的目的又三緘其口</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">machine139  </span><span class="f3 push-content">: 啊不就各自取暖，你們好雷負雷在那邊吵來吵去真的很</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">machine139  </span><span class="f3 push-content">: 無聊欸，喜歡就喜歡，不喜歡就不喜歡，一直去質疑對</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">machine139  </span><span class="f3 push-content">: 方有比較爽嗎？</span><span class="push-ipdatetime"> 10/10 23:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 我問你, 你的立場是替好雷抱不平的嗎?</span><span class="push-ipdatetime"> 10/10 23:57
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: free問z:我問你, 你的立場是替好雷抱不平的嗎?</span><span class="push-ipdatetime"> 10/10 23:57
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 懷疑XD 阿快舉證阿 舉不出來 就說別人針對他</span><span class="push-ipdatetime"> 10/10 23:57
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 因為有人就是認為是工讀生阿XD</span><span class="push-ipdatetime"> 10/10 23:57
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: Wang7752先等等 我先處理za下一個就是你</span><span class="push-ipdatetime"> 10/10 23:57
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 不要再跳真了拉 還處理我耶 我好怕喔</span><span class="push-ipdatetime"> 10/10 23:58
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 今天舉證都舉不出來 就再說因為版規的關係</span><span class="push-ipdatetime"> 10/10 23:58
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 導置好雷文很大機會是工讀生寫的 這哪門子的笑話拉</span><span class="push-ipdatetime"> 10/10 23:58
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 跳"針"</span><span class="push-ipdatetime"> 10/10 23:58
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 導"致"</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xvited945   </span><span class="f3 push-content">: za走開好不好</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 你國文老師在哭</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: ??只能抓這種錯字了阿???</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 我護航的目的:我喜歡這部片，也看到很多人喜歡這部</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 片，我很開心有同好，我們有共同的話題可以聊，我</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 們這些同好是朋友，所以我不喜歡看到有人罵我朋友</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: ，這夠清楚嗎？</span><span class="push-ipdatetime"> 10/10 23:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 翻譯:我喜歡這部所以不喜歡的我都要到人家的留言版</span><span class="push-ipdatetime"> 10/11 00:00
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 開戰</span><span class="push-ipdatetime"> 10/11 00:00
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 笑死, 那有人罵你朋友了嗎?</span><span class="push-ipdatetime"> 10/11 00:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 真的那麼喜歡的話就請你去好雷跟你所謂志同道合的</span><span class="push-ipdatetime"> 10/11 00:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 版友切磋 討論劇情啊</span><span class="push-ipdatetime"> 10/11 00:01
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 我就說，我能接受有人不喜歡這部片，但不能接受沒</span><span class="push-ipdatetime"> 10/11 00:02
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 有任何證據之前就質疑跟我一樣喜歡這部片的人是騙</span><span class="push-ipdatetime"> 10/11 00:02
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 子，這不是很好理解？</span><span class="push-ipdatetime"> 10/11 00:02
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 而不是每篇負雷區都在底下回一大堆老調重彈 似曾相</span><span class="push-ipdatetime"> 10/11 00:02
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 似的知乎也者 試圖想要帶風向好嗎</span><span class="push-ipdatetime"> 10/11 00:02
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 那就不要開地圖砲阿 很難嗎??</span><span class="push-ipdatetime"> 10/11 00:03
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 誰說你是騙子了?</span><span class="push-ipdatetime"> 10/11 00:03
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 行銷文也是朋友就是了?</span><span class="push-ipdatetime"> 10/11 00:03
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 所以工讀生=騙子嗎</span><span class="push-ipdatetime"> 10/11 00:03
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 你看 剛說完就有人馬上開地圖砲了</span><span class="push-ipdatetime"> 10/11 00:03
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ea9715234   </span><span class="f3 push-content">: ZA去好雷底下取暖就好 你是無法改變負雷人的想法的</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 那你的朋友是認真寫好文的人還是行銷文 請說明?</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 等等... 那你到不是你朋友的負雷文這邊幹麻？</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: wang這次國字打對了 但大人講話小孩子不要吵 先去</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 旁邊玩沙乖</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 人家在這邊說有可能有工讀生 你急著跳出來保護朋友</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: ？...意思是...？</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">iceskycoldly</span><span class="f3 push-content">: 覺得電影本身沒到負雷啦 但一昧噓文護航的比較討厭</span><span class="push-ipdatetime"> 10/11 00:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">iceskycoldly</span><span class="f3 push-content">: 本身沒很討厭這片 都因為這些人反而沒很喜歡這片</span><span class="push-ipdatetime"> 10/11 00:05
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 有可能就是地圖砲阿 很難懂 玩砂請你自己去玩好嗎</span><span class="push-ipdatetime"> 10/11 00:05
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: zakijudelo 你朋友是認真寫好文的人還是行銷寫手?</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 就是有人說被很多好雷文騙去看，這不就代表質疑很</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 多發好雷文的是騙子嗎？更惡劣的是暗指他們有收錢</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: ，明明沒拿到還要背這種惡名，誰能接受</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: 你先回答我問題麻</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 那請你解釋一下何謂地圖砲 以及你指涉的人或事件好</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 嗎</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 喜歡這部那就去好雷文那互相認同啊XD 在負雷文裡拼</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 命想要反駁或是解釋對我們這些不喜歡或是有所質疑的</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">djexe78     </span><span class="f3 push-content">: 版友不是很奇怪嗎？XDD</span><span class="push-ipdatetime"> 10/11 00:06
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">freedom1986 </span><span class="f3 push-content">: zakijudelo 你要不要先認真回答我問題?</span><span class="push-ipdatetime"> 10/11 00:07
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">wang7752    </span><span class="f3 push-content">: 說寫好雷的很大機會是工讀生這就是地圖砲阿zzz</span><span class="push-ipdatetime"> 10/11 00:07
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 阿我就是看很多好雷文才去看的 也沒覺得每個人都工</span><span class="push-ipdatetime"> 10/11 00:07
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kb1023      </span><span class="f3 push-content">: 讀阿</span><span class="push-ipdatetime"> 10/11 00:07
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rhappyd     </span><span class="f3 push-content">: 你要不要先釋義一下地圖砲?</span><span class="push-ipdatetime"> 10/11 00:07
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 在我沒證據證明他們有收錢之前，就是清白的啊，無</span><span class="push-ipdatetime"> 10/11 00:08
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">zakijudelo  </span><span class="f3 push-content">: 罪推定學過沒啊！要說別人有罪之前，你要提出證據</span><span class="push-ipdatetime"> 10/11 00:08
# ...
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">sunnigh27   </span><span class="f3 push-content">: 3跟4點就知道根本沒有認真在看電影，只是為噴而噴，</span><span class="push-ipdatetime"> 10/11 02:40
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">sunnigh27   </span><span class="f3 push-content">: 可悲！看電影卻在找東西罵，怎不罵鐵達尼號為什麼會</span><span class="push-ipdatetime"> 10/11 02:40
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">sunnigh27   </span><span class="f3 push-content">: 蠢到撞冰山，在要賣的車內做愛很沒功德心</span><span class="push-ipdatetime"> 10/11 02:40
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">PatlaborGao </span><span class="f3 push-content">: 為噴而噴吧 你根本可以不用浪費錢進去看</span><span class="push-ipdatetime"> 10/11 02:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">salvador1988</span><span class="f3 push-content">: 這篇以一篇負雷文來說內容已經算很有誠意了</span><span class="push-ipdatetime"> 10/11 02:52
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">salvador1988</span><span class="f3 push-content">: 希望所有被負雷比例低的事實感到困擾的人都能出來PO</span><span class="push-ipdatetime"> 10/11 02:55
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">salvador1988</span><span class="f3 push-content">: 雖然我也蠻納悶這有什麼好困擾的</span><span class="push-ipdatetime"> 10/11 02:58
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">icesean     </span><span class="f3 push-content">: 推你 護航的講話水準都蠻低的</span><span class="push-ipdatetime"> 10/11 02:59
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">underLemon  </span><span class="f3 push-content">: 劇情不合理可以嘴，但是連劇情都沒看懂就在嘴真的無</span><span class="push-ipdatetime"> 10/11 02:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">underLemon  </span><span class="f3 push-content">: 言，而且前37分鐘就是故意set梗，不懂有什麼好嘴的</span><span class="push-ipdatetime"> 10/11 02:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">underLemon  </span><span class="f3 push-content">: ？</span><span class="push-ipdatetime"> 10/11 02:59
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">kuijun228   </span><span class="f3 push-content">: 猛毒也在市中心鬧，結果沒有走司法程序，不尊重法律</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kuijun228   </span><span class="f3 push-content">: ，不尊重專業，爛片，火箭升空失敗也不尊重專業，爛</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kuijun228   </span><span class="f3 push-content">: 片</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">rainkaras   </span><span class="f3 push-content">: 第一次看電影遇到整間放映廳笑到崩潰，我覺得超級好</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rainkaras   </span><span class="f3 push-content">: 笑哈哈哈哈哈哈哈哈哈哈哈哈，這就完全的娛樂片順便</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rainkaras   </span><span class="f3 push-content">: 帶出一點拍攝影片的角度，故事就是在說怎麼拍出這部</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rainkaras   </span><span class="f3 push-content">: 糞片你還要這麼認真討論支微末節，什麼都這麼認真人</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">rainkaras   </span><span class="f3 push-content">: 生會過的很累</span><span class="push-ipdatetime"> 10/11 03:01
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">guanghagrid </span><span class="f3 push-content">: 其實從你的負雷理由裡，可以看出其實你根本沒看懂這</span><span class="push-ipdatetime"> 10/11 03:07
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">guanghagrid </span><span class="f3 push-content">: 部片，甚至把第一段跟第二段的情境混在一起談了</span><span class="push-ipdatetime"> 10/11 03:07
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">AsPerfect   </span><span class="f3 push-content">: 反正賣點就是反轉這個技巧, 很多電影的反轉不會前面</span><span class="push-ipdatetime"> 10/11 03:11
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">AsPerfect   </span><span class="f3 push-content">: 這麼爛, 個人主觀最多只能給普</span><span class="push-ipdatetime"> 10/11 03:12
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">hornet177165</span><span class="f3 push-content">: 前面就是鋪陳 我倒覺得全片都非常好看</span><span class="push-ipdatetime"> 10/11 03:13
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">AsPerfect   </span><span class="f3 push-content">: 甚至這篇文這麼多推 還以為是假負雷真好雷的反轉文</span><span class="push-ipdatetime"> 10/11 03:13
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tfvhj5681   </span><span class="f3 push-content">: 工讀生大戰工讀生 通通都是工讀生</span><span class="push-ipdatetime"> 10/11 03:40
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">marco79811  </span><span class="f3 push-content">: 你真的有看過這部電影嗎？大嬸之所以加入的原因不是</span><span class="push-ipdatetime"> 10/11 03:45
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">marco79811  </span><span class="f3 push-content">: 都有說明嗎？</span><span class="push-ipdatetime"> 10/11 03:45
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">marco79811  </span><span class="f3 push-content">: 再看了一次  你是在反串吧？</span><span class="push-ipdatetime"> 10/11 03:49
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">retsuya001  </span><span class="f3 push-content">: 為什麼負雷文總是喜歡攻擊覺得好看的人是工讀生？為</span><span class="push-ipdatetime"> 10/11 04:05
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">retsuya001  </span><span class="f3 push-content">: 什麼不正視自己就是少數派？</span><span class="push-ipdatetime"> 10/11 04:05
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">DoubleDown  </span><span class="f3 push-content">: 你去看大災難家應該也會嫌難看</span><span class="push-ipdatetime"> 10/11 04:09
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">Leonala     </span><span class="f3 push-content">: 總是看到邏輯跟腦袋很差的人想裝理性裝有個性  真的</span><span class="push-ipdatetime"> 10/11 04:40
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Leonala     </span><span class="f3 push-content">: 可憐</span><span class="push-ipdatetime"> 10/11 04:40
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Dennis0428  </span><span class="f3 push-content">: 中間喊卡只會更糟糕好嗎？ 努力想辦法完成才是大家</span><span class="push-ipdatetime"> 10/11 04:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Dennis0428  </span><span class="f3 push-content">: 感動的點。</span><span class="push-ipdatetime"> 10/11 04:49
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">fewhy       </span><span class="f3 push-content">: 為負而負幫噓</span><span class="push-ipdatetime"> 10/11 04:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">forever920fv</span><span class="f3 push-content">: 完全被影評片，謝謝原Po說中我心聲</span><span class="push-ipdatetime"> 10/11 05:07
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">forever920fv</span><span class="f3 push-content">: 騙*</span><span class="push-ipdatetime"> 10/11 05:08
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">dfc489      </span><span class="f3 push-content">: 連看都不會想去看的東西 廢到笑</span><span class="push-ipdatetime"> 10/11 05:44
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 電影主不主觀是個人感受 所以你發負雷文 覺得你這篇</span><span class="push-ipdatetime"> 10/11 06:23
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 糟的人照樣可以噓你 不是嗎</span><span class="push-ipdatetime"> 10/11 06:24
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">thekuo      </span><span class="f3 push-content">: 就一些白爛的點好笑</span><span class="push-ipdatetime"> 10/11 06:36
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 說起來 突然負雷變多 這時間點剛好跟猛毒上映的時間</span><span class="push-ipdatetime"> 10/11 06:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 點相類似 發負雷打壓這部片剛好可以拉抬猛毒的聲勢</span><span class="push-ipdatetime"> 10/11 06:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 找某些人的邏輯 我也可以合理推論懷疑最近發負雷的</span><span class="push-ipdatetime"> 10/11 06:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">IT13        </span><span class="f3 push-content">: 都是猛毒那邊派來的工讀生</span><span class="push-ipdatetime"> 10/11 06:46
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">leastsquares</span><span class="f3 push-content">: 日本笑點那麼怪 喜劇能多好看</span><span class="push-ipdatetime"> 10/11 07:37
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">GOBS        </span><span class="f3 push-content">: 好雷負雷這種主觀議題就別吵了 沒有標準答案 但是推</span><span class="push-ipdatetime"> 10/11 07:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">GOBS        </span><span class="f3 push-content">: 文在那邊說這部好雷多就是商議操作的要不要拿出證據</span><span class="push-ipdatetime"> 10/11 07:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">GOBS        </span><span class="f3 push-content">:  還是電椅板可以隨便造謠?</span><span class="push-ipdatetime"> 10/11 07:44
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">GOBS        </span><span class="f3 push-content">: *電影板</span><span class="push-ipdatetime"> 10/11 07:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">idontknowhow</span><span class="f3 push-content">: 我覺得蠻好看的啊 劇本寫得不錯</span><span class="push-ipdatetime"> 10/11 07:50
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">laechan     </span><span class="f3 push-content">: 就說反指標了你還信，狂推的完全不想看，反而像莉茲</span><span class="push-ipdatetime"> 10/11 08:02
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">laechan     </span><span class="f3 push-content">: 與青鳥這種在c洽不時看到二刷心得的才值得進場支持</span><span class="push-ipdatetime"> 10/11 08:02
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Badtwotwo   </span><span class="f3 push-content">: 覺得好看+1 但不會推薦朋友進場 太吃電波了</span><span class="push-ipdatetime"> 10/11 08:10
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">danieltu    </span><span class="f3 push-content">: 覺得不好看+1</span><span class="push-ipdatetime"> 10/11 08:13
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">s0450336    </span><span class="f3 push-content">: 你柯黑啊，造謠都要別人提證據</span><span class="push-ipdatetime"> 10/11 08:14
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">batista99   </span><span class="f3 push-content">: 最近工讀生真勤勞</span><span class="push-ipdatetime"> 10/11 08:25
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">iyawen      </span><span class="f3 push-content">: 為了一部片吵成這樣也是一絕</span><span class="push-ipdatetime"> 10/11 08:33
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lovelva00   </span><span class="f3 push-content">: 有些點其實本來就電影設定，光第三點他媽媽不是後</span><span class="push-ipdatetime"> 10/11 08:59
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lovelva00   </span><span class="f3 push-content">: 來沒接戲了..這樣反而讓人懷疑發負雷的是工讀生耶</span><span class="push-ipdatetime"> 10/11 08:59
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">snwen513    </span><span class="f3 push-content">: ？？</span><span class="push-ipdatetime"> 10/11 09:04
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">d55032574   </span><span class="f3 push-content">: <a href="https://youtu.be/lLCEUpIg8rE" rel="nofollow" target="_blank">https://youtu.be/lLCEUpIg8rE</a></span><span class="push-ipdatetime"> 10/11 09:06
# </span></div><div class="richcontent"><div class="resize-container"><div class="resize-content"><iframe allowfullscreen="" class="youtube-player" frameborder="0" src="//www.youtube.com/embed/lLCEUpIg8rE" type="text/html"></iframe></div></div></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">axe6hn29    </span><span class="f3 push-content">: 乾我看完以為推的都是想害人</span><span class="push-ipdatetime"> 10/11 09:15
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">axe6hn29    </span><span class="f3 push-content">: 有夠難看</span><span class="push-ipdatetime"> 10/11 09:15
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">VOT1077     </span><span class="f3 push-content">: 本文暫時鎖文七日冷靜</span><span class="push-ipdatetime"> 10/11 09:23
# </span></div></div>
#
#     <div data-longpollurl="/v1/longpoll?id=9a7d55e357b057d33417633c40cf855b067cfbff" data-offset="49313" data-pollurl="/poll/movie/M.1539183746.A.DF0.html?cacheKey=2100-407744549&amp;offset=49313&amp;offset-sig=0aaa1f30604b5e338b4063ed4b31e0406eff98fc" id="article-polling"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#
#
# </body></html>
